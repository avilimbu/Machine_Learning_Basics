# %%
import numpy as np

# %%
a = np.arange(6).reshape(2,3)
a
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
# ndim | Gives the dimension of the array
a.ndim
# Out:
# 2

# %%
# shape | Gives the shape of the array
a.shape
# Out:
# (2, 3)

# %%
# size | Gives the size
a.size
# Out:
# 6

# %%
# dtype | Shows the type of the elements
a.dtype
# Out:
# dtype('int64')

# %%
# itemsize | returns the length of one array element in bytes.
a.itemsize
# Out:
# 8

# %%
# creating the array
b = np.array([
    [1,2,3],
    [4,5,6]
])
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
